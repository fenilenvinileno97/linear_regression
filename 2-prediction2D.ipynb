# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
u = np.array([1,1])
v = np.array([-1,-1])

# %%
# lm.plot_vector(vecs=[u,v], cols=["red", "blue"])
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.show()
# Out:
# (-1.5, 1.5)
