# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import linmodules as lm
from IPython.utils.capture import capture_output

# %% [markdown]
# ## Multivariate linear regression
#
# $$
# \hat{y} = a_{0}x_{0} + a_{1}x_{1} + ... a_{n}x_{n}
# $$

# %%
with capture_output() as stdout:
    # %run -i "./1-intro.ipynb"

# %%
sns.heatmap(data=housing_raw_df.corr(), cbar=True, cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>
